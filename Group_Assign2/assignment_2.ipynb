# %%
import pandas as pd
import numpy as np

counties = pd.read_csv("data/counties_table.csv")
counties = counties[counties["state"] == "Washington"].reset_index(drop=True)
counties
# Out:
#    year   fips  pop2010  pop2023       state stateCode  growthSince2010  \
# 0  2023  53033  1931249  2371204  Washington        WA         0.227809
# 1  2023  53053   795225   958900  Washington        WA         0.205822
# 2  2023  53061   713335   862343  Washington        WA         0.208889
# 3  2023  53063   471221   559775  Washington        WA         0.187925
# 4  2023  53011   425363   526696  Washington        WA         0.238227
# 5  2023  53067   252264   307552  Washington        WA         0.219167
# 6  2023  53035   251133   282955  Washington        WA         0.126714
# 7  2023  53077   243231   260778  Washington        WA         0.072141
# 8  2023  53073   201140   234560  Washington        WA         0.166153
# 9  2023  53005   175177   216383  Washington        WA         0.235225
#
#                name           ctyname                 slug  landArea  \
# 0       King County       King County       king-county-wa      2116
# ...

# %%
pres_results = pd.read_csv("data/2020_election_results.csv")
pres_results
# Out:
#     Legislative District Turnout_Registered Voters Turnout_Ballots Cast  \
# 0                      1                   106,217               93,372
# 1                      2                   106,280               86,171
# 2                      3                    91,050               70,214
# 3                      4                   113,683               93,601
# 4                      5                   110,814               97,471
# 5                      6                   107,630               90,057
# 6                      7                   106,783               89,895
# 7                      8                   100,696               82,892
# 8                      9                    85,769               71,484
# 9                     10                   111,652               96,776
# 10                    11                    89,463               72,288
# 11                    12                    93,009               79,217
# ...

# %%
demographics = pd.read_csv("census_demographics.csv")
### Year 1 = 2020 census, other years are projections and therefore not relevant.
demographics = demographics[demographics['YEAR']==1].reset_index(drop=True)

### THE NEXT LEVEL OF DATA IS GRANULAR AT THE LEVEL OF AGES. THE PARAMETERS OF THE ASSIGNMENT DO NOT SPECIFY TAKING AGE INTO ACCOUNT SO I WILL AGGREGATE. 

identifier_fields=[
    'SUMLEV',
    'STATE',
    'COUNTY',
    'STNAME',
    'CTYNAM', 
    'YEAR']




demographics = demographics.groupby
# Out:
#      SUMLEV  STATE  COUNTY      STNAME        CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0        50     53       1  Washington   Adams County     1       0    20612
# 1        50     53       1  Washington   Adams County     1       1     1887
# 2        50     53       1  Washington   Adams County     1       2     2082
# 3        50     53       1  Washington   Adams County     1       3     2199
# 4        50     53       1  Washington   Adams County     1       4     1821
# ..      ...    ...     ...         ...            ...   ...     ...      ...
# 736      50     53      77  Washington  Yakima County     1      14    11565
# 737      50     53      77  Washington  Yakima County     1      15     9469
# 738      50     53      77  Washington  Yakima County     1      16     6432
# 739      50     53      77  Washington  Yakima County     1      17     4096
# 740      50     53      77  Washington  Yakima County     1      18     4251
#
# ...
